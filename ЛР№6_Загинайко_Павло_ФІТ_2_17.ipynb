# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakmik/NM/blob/main/%D0%9B%D0%A0%E2%84%966_%D0%97%D0%B0%D0%B3%D0%B8%D0%BD%D0%B0%D0%B9%D0%BA%D0%BE_%D0%9F%D0%B0%D0%B2%D0%BB%D0%BE_%D0%A4%D0%86%D0%A2_2_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторна робота №6
#
# Варіант 8

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, expand
from scipy.interpolate import lagrange

# %%
x=np.array([-3.,-2.,0.,2.], dtype=float)
y=np.array([-22.,-13.,-7.,23.], dtype=float)

x1 = -4
x2 = 1.5
x3 = -1
x4 = 1.5

def lagrange_interpolation(x, y, x_test):
    n = len(x)
    p = np.zeros(n)  # масив для зберігання значень багаточленів L_i

    for i in range(n):
        # обчислюємо багаточлен L_i
        p_i = 1
        for j in range(n):
            if i != j:
                p_i *= (x_test - x[j]) / (x[i] - x[j])
        p[i] = p_i

    return np.dot(y, p)  # повертаємо значення багаточлена (сума y_i * L_i)

# Обчислюємо інтерполяційний багаточлен та його значення у точках
f1 = lagrange_interpolation(x, y, x1)
print("Значення функції у точці x_1 =", f1.round(4))

f2 = lagrange_interpolation(x, y, x2)
print("Значення функції у точці x_2 =", f2.round(4))

f3 = lagrange_interpolation(x, y, x3)
print("Значення функції у точці x_3 =", f3.round(4))

f4 = lagrange_interpolation(x, y, x4)
print("Значення функції у точці x_4 =", f4.round(4))
# Out:
# Значення функції у точці x_1 = -43.0
# Значення функції у точці x_2 = 10.625
# Значення функції у точці x_3 = -10.0
# Значення функції у точці x_4 = 10.625

# %%
xnew=np.linspace(np.min(x),np.max(x),100) #точки, за якими будуємо графік
ynew=[lagrange_interpolation(x,y,i) for i in xnew]
plt.plot(x,y,'o',xnew,ynew) #будуємо графік функції Лагранжа
plt.plot(x1,f1,'ro')
plt.plot(x2,f2,'ro')
plt.plot(x3,f3,'ro')
plt.plot(x4,f4,'ro')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Lagrange Polynomial_1')
plt.grid(True)
plt.show()

# %%
#Перевірка
f = lagrange(x, y)
fig = plt.figure(figsize = (7,5))
plt.plot(xnew, f(xnew), 'b', x, y, 'ro')
plt.title('Lagrange Polynomial_2')
plt.plot(x1,f1,'o')
plt.plot(x2,f2,'o')
plt.plot(x3,f3,'o')
plt.plot(x4,f4,'o')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
# Вузли інтерполяції
x = np.array([3, 4, 5, 6], dtype=float)

def f_x(x):
    return 3 / (x + 1)

# Обчислюємо значення функції у вузлах
y_data = f_x(x)

print('x =', x)
print('f_x(x) =', y_data)
print('shapes:', x.shape, y_data.shape)

# Інтерполяційний поліном Лагранжа
p = lagrange(x, y_data)
print('Поліном Лагранжа p(x):')
print(p)
print('Ступінь полінома:', p.order)
print(f'Значення в точці 5.5: {p(5.5)}')

# Точки для графіка
z = np.linspace(np.min(x), np.max(x), 100)

# Графік
plt.plot(z, p(z), '-', label='$L(x)$')
plt.plot(x, y_data, 'o', label='data')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# x = [3. 4. 5. 6.]
# f_x(x) = [0.75       0.6        0.5        0.42857143]
# shapes: (4,) (4,)
# Поліном Лагранжа p(x):
#            3           2
# -0.003571 x + 0.06786 x - 0.4929 x + 1.714
# Ступінь полінома: 3
# Значення в точці 5.5: 0.4620535714285845
